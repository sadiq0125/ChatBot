# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiq0125/ChatBot/blob/main/ChatBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
# If you're running on Colab, you will need to install the Google Generative AI SDK for Python.
# If you're running locally, you can install it using pip install google-generativeai
# !pip install -q google-generativeai

# %%
import google.generativeai as genai

# Paste your API key here
API_KEY = "AIzaSyBKdYeViNuS8wvSUBHBfuhlPe55ee0HAq8" # <--- REPLACE WITH YOUR ACTUAL NEW API KEY

# Configuration is handled when the model is loaded.
print("✅ API Key is set to be used!")
# Out:
# ✅ API Key is set to be used!

# %%
try:
    import google.generativeai as genai
    print("✅ google.generativeai is installed and imported successfully!")
except ImportError:
    print("❌ google.generativeai is not installed or cannot be imported.")
# Out:
# ✅ google.generativeai is installed and imported successfully!

# %%
# Load Gemini model
# Configure the API key globally
genai.configure(api_key=API_KEY)

# Instantiate the GenerativeModel without passing api_key
model = genai.GenerativeModel("gemini-flash-latest")

# Start a chat session (this keeps conversation history)
chat = model.start_chat(history=[])

print("🤖 Chatbot is ready! Type your message below.")
# Out:
# 🤖 Chatbot is ready! Type your message below.

# %%
import google.generativeai as genai

genai.configure(api_key=API_KEY)

try:
    print("Listing available models to verify API key...")
    for m in genai.list_models():
        print(f"Model Name: {m.name}")
    print("✅ API key verified: Successfully listed models.")
except Exception as e:
    print(f"❌ API key verification failed: {e}")
    print("Please ensure your API_KEY variable in cell QF5pVsdWEep0 is correct and re-run that cell, then this cell.")
# Out:
# Listing available models to verify API key...
# Model Name: models/gemini-2.5-flash
# Model Name: models/gemini-2.5-pro
# Model Name: models/gemini-2.0-flash
# Model Name: models/gemini-2.0-flash-001
# Model Name: models/gemini-2.0-flash-lite-001
# Model Name: models/gemini-2.0-flash-lite
# Model Name: models/gemini-2.5-flash-preview-tts
# Model Name: models/gemini-2.5-pro-preview-tts
# Model Name: models/gemma-3-1b-it
# Model Name: models/gemma-3-4b-it
# Model Name: models/gemma-3-12b-it
# Model Name: models/gemma-3-27b-it
# Model Name: models/gemma-3n-e4b-it
# Model Name: models/gemma-3n-e2b-it
# Model Name: models/gemini-flash-latest
# Model Name: models/gemini-flash-lite-latest
# Model Name: models/gemini-pro-latest
# Model Name: models/gemini-2.5-flash-lite
# Model Name: models/gemini-2.5-flash-image
# Model Name: models/gemini-2.5-flash-lite-preview-09-2025
# Model Name: models/gemini-3-pro-preview
# Model Name: models/gemini-3-flash-preview
# ...

# %%
print("🤖 Gemini Chatbot Started!")
print("Type 'quit' or 'exit' to stop.\n")

# Reset chat history for a fresh conversation
chat = model.start_chat(history=[])

while True:
    user_input = input("You: ").strip()

    # Exit condition
    if user_input.lower() in ["quit", "exit", "bye"]:
        print("Bot: Goodbye! 👋")
        break

    # Skip empty input
    if not user_input:
        continue

    # Get response from Gemini
    response = chat.send_message(user_input)
    print(f"Bot: {response.text}\n")
# Out:
# 🤖 Gemini Chatbot Started!
# Type 'quit' or 'exit' to stop.
#
# You: hi
# Bot: Hello! How can I help you today?
#
# You: when is chatbot came
# Bot: The history of chatbots goes back much further than most people realize. Here is a timeline of the key moments when chatbots "came" to be:
#
# ### 1. The First Chatbot: ELIZA (1966)
# The very first chatbot, named **ELIZA**, was created by Joseph Weizenbaum at MIT in 1966.
# * **How it worked:** It used "pattern matching" to mimic a psychotherapist. If you said, "My head hurts," ELIZA might respond, "Why do you say your head hurts?"
# * **Impact:** Even though it was simple, it surprised people by how much it felt like a real conversation.
#
# ### 2. The Paranoid Chatbot: PARRY (1972)
# In 1972, psychiatrist Kenneth Colby created **PARRY**.
# * **How it worked:** While ELIZA acted like a doctor, PARRY acted like a patient with schizophrenia.
# ...
